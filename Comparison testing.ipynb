# %%
from gurobipy import *

M = Model()
# number of players in the team
n = 15
# player strength list, either 2.5 or 3.0 for each player - TODO: get actual player strengths
N = [2.5, 3.0, 2.5, 3.0, 2.5, 3.0, 3.0, 2.5, 2.5, 3.0, 3.0, 3.0, 3.0, 3.0, 2.5]
# opponent strength list, either 2.5 or 3.0 for each court position
N0 = [3.0, 3.0, 3.0, 3.0, 3.0, 2.5, 3.0, 3.0]
# number of games in the tournament
m = 8
# number of slots for a player to play in per game
o = 8
# minimum number of games each player must play
p = 2
# availability matrix. 1 if the ith player can make the jth game, 0 if they cannot
A = [[0 for j in range(m)] for i in range(n)]
A[3][0] = 1
A[12][0] = 1
A[5][0] = 1
A[10][0] = 1
A[2][0] = 1
A[4][0] = 1
A[13][0] = 1
A[6][0] = 1

A[12][1] = 1
A[5][1] = 1
A[8][1] = 1
A[11][1] = 1
A[10][1] = 1
A[1][1] = 1
A[13][1] = 1
A[14][1] = 1

A[9][2] = 1
A[14][2] = 1
A[8][2] = 1
A[5][2] = 1
A[0][2] = 1
A[7][2] = 1
A[1][2] = 1
A[13][2] = 1

A[1][3] = 1
A[9][3] = 1
A[12][3] = 1
A[14][3] = 1
A[4][3] = 1
A[3][3] = 1
A[13][3] = 1
A[6][3] = 1

A[14][4] = 1
A[12][4] = 1
A[9][4] = 1
A[11][4] = 1
A[1][4] = 1
A[4][4] = 1
A[13][4] = 1
A[6][4] = 1

A[14][5] = 1
A[12][5] = 1
A[1][5] = 1
A[5][5] = 1
A[2][5] = 1
A[7][5] = 1
A[13][5] = 1
A[6][5] = 1

A[3][6] = 1
A[12][6] = 1
A[1][6] = 1
A[9][6] = 1
A[0][6] = 1
A[10][6] = 1
A[13][6] = 1
A[6][6] = 1

A[1][7] = 1
A[5][7] = 1
A[11][7] = 1
A[2][7] = 1
A[4][7] = 1
A[13][7] = 1
A[6][7] = 1
# preference matrix. 1 if the ith player prefers the jth game and kth slot, -1 if they prefer not to, 0 if no preference
P = [[[0 for k in range(o)] for j in range(m)] for i in range(n)] 
for j in range(0,m):
    P[6][j][6] = 1 
    P[6][j][7] = 1 
    P[13][j][6] = 1
    P[13][j][7] = 1
# constant terms for each objective optimization, in order of: balanced games, spread schedules, high win %, player preferences,
# and heavily unbalanced (2.5/2.5 vs 3.0/3.0) matches
C = [4, 1.5, .2, 1, 40]
# 1 if a player i plays in game j on the kth court, 0 if they do not
x = M.addVars(n, m, o, vtype=GRB.BINARY)
# 0 if the kth court for the jth game is balanced or favors the Romanian team, 1 if it disfavors the Romanian team
bal = M.addVars(m,5, vtype=GRB.BINARY)
# 0 if the kth court for the jth game is balanced or favors the Romanian team, 1 if it heavily disfavors the Romanian team
bal2 = M.addVars(m,5, vtype=GRB.BINARY)
# 0 if the ith player does not play consecutive matches starting with the jth game. 1 if they do
inds = M.addVars(n,m, vtype=GRB.BINARY)

M.update()

for i in range(0,n):
    M.addConstrs(x.sum(i, j, '*') <= A[i][j] for j in range(0,m)) #players can only play one court in a match, 
                                                                  #or none if they are not available
    M.addConstr(x.sum(i, '*', '*'), GRB.GREATER_EQUAL, p) #players must play at least p games in the season
    for j in range(0,m-1):
        M.addConstr(x.sum(i, j, '*') + x.sum(i,j+1, '*') - inds[i,j] <= 1) #ensures that inds[i,j] will be 1 if consecutive games

for j in range(0,m):
    for k in [0,2,4]:
        expr = LinExpr(-1*N0[k]-N0[k+1])
        for i in range(0,n):
            expr.add(x[i,j,k], N[i])
            expr.add(x[i,j,k+1], N[i])
        expr.add(bal[j, int((k+1)/2)], .5)
        expr.add(bal2[j, int((k+1)/2)], 3)
        M.addConstr(expr >= 0) #ensures that bal[j,k] for the doubles courts will be 0 if the romanian team is at least as strong
    for k in [6,7]:
        expr = LinExpr(-1*N0[k])
        for i in range(0,n):
            expr.add(x[i,j,k], N[i])
        expr.add(bal[j, k-3], .5)
        expr.add(bal2[j, k-3], 3)
        M.addConstr(expr >= 0) #ensures that bal[j,k] for the singles courts will be 0 if the romanian team is at least as strong

for k in range(0,o):
    M.addConstrs(x.sum('*', j, k) <= 1 for j in range(0,m)) #all courts must have at most one player

M.update()
        
expr = LinExpr(m*sum(N0)*-1*C[2]) # subtracts overall opposing team strength from objective function
opponentSum = 0;
for k in range(0,o):
    for j in range(0,m):
        opponentSum += N0[j]
        for i in range(0,5):
            expr.add(bal[j,i], -1*C[0]) # attempt to balance as many matches as possible
            expr.addConstant(C[0])
            expr.add(bal2[j,i], -1*C[4]) # attempt to balance as many matches as possible
        for i in range(0,n):
            expr.add(x[i,j,k], N[i]*C[2]) # "overall team strength" - TODO: maybe rework condition?
            expr.add(x[i,j,k], P[i][j][k]*C[3]) # preferences
            expr.add(inds[i,j], -1*C[1]) #consecutive games penalty

M.setObjective(expr, GRB.MAXIMIZE)

M.optimize()

#Print out some reasonable output
for i in range (0,n):
    matches = ""
    for j in range (0,m):
        for k in range(0,o):
            if x[i,j,k].x == 1:
                matches += "(" + str(j) + "," + str(k) + ")"
    print("player " + str(i) + " plays at " + matches)
   
print()
for j in range (0,m):
    print("Match " + str(j + 1))
    for k in range (0,o):
        for i in range (0,n):
            if x[i,j,k].x == 1:
                print("Player " + str(i) + "(" + str(N[i]) + ") on slot " + str(k) + " against " + str(N0[k]))
# Out:
# Optimize a model with 344 rows, 1160 columns and 5705 nonzeros
# Variable types: 0 continuous, 1160 integer (1160 binary)
# Coefficient statistics:
#   Matrix range     [5e-01, 3e+00]
#   Objective range  [5e-01, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -2939.600000
# Presolve removed 131 rows and 545 columns
# Presolve time: 0.01s
# Presolved: 213 rows, 615 columns, 2623 nonzeros
# Variable types: 0 continuous, 615 integer (615 binary)
#
# Root relaxation: objective 3.534000e+02, 381 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  353.40000    0    7 -2939.6000  353.40000   112%     -    0s
# H    0     0                     268.4000000  353.40000  31.7%     -    0s
#      0     0 infeasible    0       268.40000  268.40000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 4
#
# Explored 1 nodes (427 simplex iterations) in 0.07 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 268.4 -2939.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.684000000000e+02, best bound 2.684000000000e+02, gap 0.0000%
# player 0 plays at (2,5)(6,5)
# player 1 plays at (1,7)(2,1)(3,1)(4,0)(5,0)(6,1)(7,0)
# player 2 plays at (0,2)(5,2)(7,1)
# player 3 plays at (0,3)(3,3)(6,2)
# player 4 plays at (0,5)(3,2)(4,1)(7,5)
# player 5 plays at (0,4)(1,3)(2,3)(5,4)(7,4)
# player 6 plays at (0,6)(3,6)(4,6)(5,6)(6,7)(7,7)
# player 7 plays at (2,2)(5,1)
# player 8 plays at (1,4)(2,4)
# player 9 plays at (2,7)(3,0)(4,2)(6,3)
# player 10 plays at (0,1)(1,5)(6,4)
# player 11 plays at (1,2)(4,4)(7,3)
# player 12 plays at (0,0)(1,1)(3,4)(4,3)(5,3)(6,0)
# player 13 plays at (0,7)(1,6)(2,6)(3,7)(4,7)(5,7)(6,6)(7,6)
# player 14 plays at (1,0)(2,0)(3,5)(4,5)(5,5)
#
# Match 1
# Player 12(3.0) on slot 0 against 3.0
# Player 10(3.0) on slot 1 against 3.0
# Player 2(2.5) on slot 2 against 3.0
# Player 3(3.0) on slot 3 against 3.0
# Player 5(3.0) on slot 4 against 3.0
# Player 4(2.5) on slot 5 against 2.5
# Player 6(3.0) on slot 6 against 3.0
# Player 13(3.0) on slot 7 against 3.0
# Match 2
# Player 14(2.5) on slot 0 against 3.0
# Player 12(3.0) on slot 1 against 3.0
# Player 11(3.0) on slot 2 against 3.0
# Player 5(3.0) on slot 3 against 3.0
# Player 8(2.5) on slot 4 against 3.0
# Player 10(3.0) on slot 5 against 2.5
# Player 13(3.0) on slot 6 against 3.0
# Player 1(3.0) on slot 7 against 3.0
# Match 3
# Player 14(2.5) on slot 0 against 3.0
# Player 1(3.0) on slot 1 against 3.0
# Player 7(2.5) on slot 2 against 3.0
# Player 5(3.0) on slot 3 against 3.0
# Player 8(2.5) on slot 4 against 3.0
# Player 0(2.5) on slot 5 against 2.5
# Player 13(3.0) on slot 6 against 3.0
# Player 9(3.0) on slot 7 against 3.0
# Match 4
# Player 9(3.0) on slot 0 against 3.0
# Player 1(3.0) on slot 1 against 3.0
# Player 4(2.5) on slot 2 against 3.0
# Player 3(3.0) on slot 3 against 3.0
# Player 12(3.0) on slot 4 against 3.0
# Player 14(2.5) on slot 5 against 2.5
# Player 6(3.0) on slot 6 against 3.0
# Player 13(3.0) on slot 7 against 3.0
# Match 5
# Player 1(3.0) on slot 0 against 3.0
# Player 4(2.5) on slot 1 against 3.0
# Player 9(3.0) on slot 2 against 3.0
# Player 12(3.0) on slot 3 against 3.0
# Player 11(3.0) on slot 4 against 3.0
# Player 14(2.5) on slot 5 against 2.5
# Player 6(3.0) on slot 6 against 3.0
# Player 13(3.0) on slot 7 against 3.0
# Match 6
# Player 1(3.0) on slot 0 against 3.0
# Player 7(2.5) on slot 1 against 3.0
# Player 2(2.5) on slot 2 against 3.0
# Player 12(3.0) on slot 3 against 3.0
# Player 5(3.0) on slot 4 against 3.0
# Player 14(2.5) on slot 5 against 2.5
# Player 6(3.0) on slot 6 against 3.0
# Player 13(3.0) on slot 7 against 3.0
# Match 7
# Player 12(3.0) on slot 0 against 3.0
# Player 1(3.0) on slot 1 against 3.0
# Player 3(3.0) on slot 2 against 3.0
# Player 9(3.0) on slot 3 against 3.0
# Player 10(3.0) on slot 4 against 3.0
# Player 0(2.5) on slot 5 against 2.5
# Player 13(3.0) on slot 6 against 3.0
# Player 6(3.0) on slot 7 against 3.0
# Match 8
# Player 1(3.0) on slot 0 against 3.0
# Player 2(2.5) on slot 1 against 3.0
# Player 11(3.0) on slot 3 against 3.0
# Player 5(3.0) on slot 4 against 3.0
# Player 4(2.5) on slot 5 against 2.5
# Player 13(3.0) on slot 6 against 3.0
# Player 6(3.0) on slot 7 against 3.0

# %%
sumBal = 0
sumPref = 0
sumConsec = 0
sumStr = 0
for j in range(0,m):
    for k in range(0,5):
        sumBal += bal[j,k].x
        sumBal += 10*bal2[j,k].x
for i in range(0,n):
    for j in range(0,m):
        sumConsec += inds[i,j].x
        for k in range(0,o):
            sumPref += P[i][j][k]*x[i,j,k].x
            sumStr += x[i,j,k].x*N[i]

print(sumBal)
print(sumPref)
print(sumConsec)
print(sumStr)
# Out:
# 15.0
# 14.0
# 30.0
# 182.5

# %%
from gurobipy import *

M = Model()
# number of players in the team
n = 15
# player strength list, either 2.5 or 3.0 for each player - TODO: get actual player strengths
N = [2.5, 3.0, 2.5, 3.0, 2.5, 3.0, 3.0, 2.5, 2.5, 3.0, 3.0, 3.0, 3.0, 3.0, 2.5]
# opponent strength list, either 2.5 or 3.0 for each court position
N0 = [3.0, 3.0, 3.0, 3.0, 3.0, 2.5, 3.0, 3.0]
# number of games in the tournament
m = 8
# number of slots for a player to play in per game
o = 8
# minimum number of games each player must play
p = 2
# availability matrix. 1 if the ith player can make the jth game, 0 if they cannot
A = [[0 for j in range(m)] for i in range(n)]
A[3][0] = 1
A[12][0] = 1
A[5][0] = 1
A[10][0] = 1
A[2][0] = 1
A[4][0] = 1
A[13][0] = 1
A[6][0] = 1
A[0][0] = 1
A[8][0] = 1
A[1][0] = 1

A[12][1] = 1
A[5][1] = 1
A[8][1] = 1
A[11][1] = 1
A[10][1] = 1
A[1][1] = 1
A[13][1] = 1
A[14][1] = 1
A[2][1] = 1
A[4][1] = 1
A[0][1] = 1
A[7][1] = 1

A[9][2] = 1
A[14][2] = 1
A[8][2] = 1
A[5][2] = 1
A[0][2] = 1
A[7][2] = 1
A[1][2] = 1
A[13][2] = 1
A[3][2] = 1
A[4][2] = 1
A[2][2] = 1
A[10][2] = 1

A[1][3] = 1
A[9][3] = 1
A[12][3] = 1
A[14][3] = 1
A[4][3] = 1
A[3][3] = 1
A[13][3] = 1
A[6][3] = 1
A[2][3] = 1
A[5][3] = 1
A[10][3] = 1

A[14][4] = 1
A[12][4] = 1
A[9][4] = 1
A[11][4] = 1
A[1][4] = 1
A[4][4] = 1
A[13][4] = 1
A[6][4] = 1
A[2][4] = 1
A[0][4] = 1
A[8][4] = 1
A[7][4] = 1

A[14][5] = 1
A[12][5] = 1
A[1][5] = 1
A[5][5] = 1
A[2][5] = 1
A[7][5] = 1
A[13][5] = 1
A[6][5] = 1
A[0][5] = 1
A[11][5] = 1

A[3][6] = 1
A[12][6] = 1
A[1][6] = 1
A[9][6] = 1
A[0][6] = 1
A[10][6] = 1
A[13][6] = 1
A[6][6] = 1
A[4][6] = 1
A[5][6] = 1
A[8][6] = 1
A[7][6] = 1
A[2][6] = 1

A[1][7] = 1
A[5][7] = 1
A[11][7] = 1
A[2][7] = 1
A[4][7] = 1
A[13][7] = 1
A[6][7] = 1
# preference matrix. 1 if the ith player prefers the jth game and kth slot, -1 if they prefer not to, 0 if no preference
P = [[[0 for k in range(o)] for j in range(m)] for i in range(n)] 
for j in range(0,m):
    P[6][j][6] = 1 
    P[6][j][7] = 1 
    P[13][j][6] = 1
    P[13][j][7] = 1
# constant terms for each objective optimization, in order of: balanced games, spread schedules, high win %, player preferences,
# and heavily unbalanced (2.5/2.5 vs 3.0/3.0) matches
C = [4, 1.5, .2, 1, 40]
# 1 if a player i plays in game j on the kth court, 0 if they do not
x = M.addVars(n, m, o, vtype=GRB.BINARY)
# 0 if the kth court for the jth game is balanced or favors the Romanian team, 1 if it disfavors the Romanian team
bal = M.addVars(m,5, vtype=GRB.BINARY)
# 0 if the kth court for the jth game is balanced or favors the Romanian team, 1 if it heavily disfavors the Romanian team
bal2 = M.addVars(m,5, vtype=GRB.BINARY)
# 0 if the ith player does not play consecutive matches starting with the jth game. 1 if they do
inds = M.addVars(n,m, vtype=GRB.BINARY)

M.update()

for i in range(0,n):
    M.addConstrs(x.sum(i, j, '*') <= A[i][j] for j in range(0,m)) #players can only play one court in a match, 
                                                                  #or none if they are not available
    M.addConstr(x.sum(i, '*', '*'), GRB.GREATER_EQUAL, p) #players must play at least p games in the season
    for j in range(0,m-1):
        M.addConstr(x.sum(i, j, '*') + x.sum(i,j+1, '*') - inds[i,j] <= 1) #ensures that inds[i,j] will be 1 if consecutive games

for j in range(0,m):
    for k in [0,2,4]:
        expr = LinExpr(-1*N0[k]-N0[k+1])
        for i in range(0,n):
            expr.add(x[i,j,k], N[i])
            expr.add(x[i,j,k+1], N[i])
        expr.add(bal[j, int((k+1)/2)], .5)
        expr.add(bal2[j, int((k+1)/2)], 3)
        M.addConstr(expr >= 0) #ensures that bal[j,k] for the doubles courts will be 0 if the romanian team is at least as strong
    for k in [6,7]:
        expr = LinExpr(-1*N0[k])
        for i in range(0,n):
            expr.add(x[i,j,k], N[i])
        expr.add(bal[j, k-3], .5)
        expr.add(bal2[j, k-3], 3)
        M.addConstr(expr >= 0) #ensures that bal[j,k] for the singles courts will be 0 if the romanian team is at least as strong

for k in range(0,o):
    M.addConstrs(x.sum('*', j, k) <= 1 for j in range(0,m)) #all courts must at most one player

M.update()
        
expr = LinExpr(m*sum(N0)*-1*C[2]) # subtracts overall opposing team strength from objective function
opponentSum = 0;
for k in range(0,o):
    for j in range(0,m):
        opponentSum += N0[j]
        for i in range(0,5):
            expr.add(bal[j,i], -1*C[0]) # attempt to balance as many matches as possible
            expr.addConstant(C[0])
            expr.add(bal2[j,i], -1*C[4]) # attempt to balance as many matches as possible
        for i in range(0,n):
            expr.add(x[i,j,k], N[i]*C[2]) # "overall team strength" - TODO: maybe rework condition?
            expr.add(x[i,j,k], P[i][j][k]*C[3]) # preferences
            expr.add(inds[i,j], -1*C[1]) #consecutive games penalty

M.setObjective(expr, GRB.MAXIMIZE)

M.optimize()

#Print out some reasonable output
for i in range (0,n):
    matches = ""
    for j in range (0,m):
        for k in range(0,o):
            if x[i,j,k].x == 1:
                matches += "(" + str(j) + "," + str(k) + ")"
    print("player " + str(i) + " plays at " + matches)
   
print()
for j in range (0,m):
    print("Match " + str(j + 1))
    for k in range (0,o):
        for i in range (0,n):
            if x[i,j,k].x == 1:
                print("Player " + str(i) + "(" + str(N[i]) + ") on slot " + str(k) + " against " + str(N0[k]))
# Out:
# Optimize a model with 344 rows, 1160 columns and 5705 nonzeros
# Variable types: 0 continuous, 1160 integer (1160 binary)
# Coefficient statistics:
#   Matrix range     [5e-01, 3e+00]
#   Objective range  [5e-01, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective -4529.500000
# Presolve removed 78 rows and 317 columns
# Presolve time: 0.01s
# Presolved: 266 rows, 843 columns, 3899 nonzeros
# Variable types: 0 continuous, 843 integer (843 binary)
#
# Root relaxation: objective 5.379000e+02, 1386 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  537.90000    0    9 -4529.5000  537.90000   112%     -    0s
# H    0     0                     420.9000000  537.90000  27.8%     -    0s
# *    0     0               0     452.9000000  452.90000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 4
#
# Explored 1 nodes (1388 simplex iterations) in 0.09 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 452.9 420.9 -4529.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.529000000000e+02, best bound 4.529000000000e+02, gap 0.0000%
# player 0 plays at (0,5)(2,7)(4,3)
# player 1 plays at (0,1)(1,1)(2,2)(3,3)(4,0)(5,1)(6,4)(7,5)
# player 2 plays at (5,4)(7,1)
# player 3 plays at (0,4)(2,5)(3,4)(6,2)
# player 4 plays at (3,5)(7,4)
# player 5 plays at (0,3)(1,4)(2,0)(3,0)(5,3)(7,0)
# player 6 plays at (0,7)(3,6)(4,7)(5,6)(6,7)(7,6)
# player 7 plays at (1,3)(4,4)
# player 8 plays at (2,4)(6,5)
# player 9 plays at (2,1)(4,1)(6,1)
# player 10 plays at (0,2)(1,0)(2,3)(3,2)(6,3)
# player 11 plays at (1,2)(4,2)(5,2)(7,2)
# player 12 plays at (0,0)(1,7)(3,1)(4,5)(5,0)(6,0)
# player 13 plays at (0,6)(1,6)(2,6)(3,7)(4,6)(5,7)(6,6)(7,7)
# player 14 plays at (1,5)(5,5)
#
# Match 1
# Player 12(3.0) on slot 0 against 3.0
# Player 1(3.0) on slot 1 against 3.0
# Player 10(3.0) on slot 2 against 3.0
# Player 5(3.0) on slot 3 against 3.0
# Player 3(3.0) on slot 4 against 3.0
# Player 0(2.5) on slot 5 against 2.5
# Player 13(3.0) on slot 6 against 3.0
# Player 6(3.0) on slot 7 against 3.0
# Match 2
# Player 10(3.0) on slot 0 against 3.0
# Player 1(3.0) on slot 1 against 3.0
# Player 11(3.0) on slot 2 against 3.0
# Player 7(2.5) on slot 3 against 3.0
# Player 5(3.0) on slot 4 against 3.0
# Player 14(2.5) on slot 5 against 2.5
# Player 13(3.0) on slot 6 against 3.0
# Player 12(3.0) on slot 7 against 3.0
# Match 3
# Player 5(3.0) on slot 0 against 3.0
# Player 9(3.0) on slot 1 against 3.0
# Player 1(3.0) on slot 2 against 3.0
# Player 10(3.0) on slot 3 against 3.0
# Player 8(2.5) on slot 4 against 3.0
# Player 3(3.0) on slot 5 against 2.5
# Player 13(3.0) on slot 6 against 3.0
# Player 0(2.5) on slot 7 against 3.0
# Match 4
# Player 5(3.0) on slot 0 against 3.0
# Player 12(3.0) on slot 1 against 3.0
# Player 10(3.0) on slot 2 against 3.0
# Player 1(3.0) on slot 3 against 3.0
# Player 3(3.0) on slot 4 against 3.0
# Player 4(2.5) on slot 5 against 2.5
# Player 6(3.0) on slot 6 against 3.0
# Player 13(3.0) on slot 7 against 3.0
# Match 5
# Player 1(3.0) on slot 0 against 3.0
# Player 9(3.0) on slot 1 against 3.0
# Player 11(3.0) on slot 2 against 3.0
# Player 0(2.5) on slot 3 against 3.0
# Player 7(2.5) on slot 4 against 3.0
# Player 12(3.0) on slot 5 against 2.5
# Player 13(3.0) on slot 6 against 3.0
# Player 6(3.0) on slot 7 against 3.0
# Match 6
# Player 12(3.0) on slot 0 against 3.0
# Player 1(3.0) on slot 1 against 3.0
# Player 11(3.0) on slot 2 against 3.0
# Player 5(3.0) on slot 3 against 3.0
# Player 2(2.5) on slot 4 against 3.0
# Player 14(2.5) on slot 5 against 2.5
# Player 6(3.0) on slot 6 against 3.0
# Player 13(3.0) on slot 7 against 3.0
# Match 7
# Player 12(3.0) on slot 0 against 3.0
# Player 9(3.0) on slot 1 against 3.0
# Player 3(3.0) on slot 2 against 3.0
# Player 10(3.0) on slot 3 against 3.0
# Player 1(3.0) on slot 4 against 3.0
# Player 8(2.5) on slot 5 against 2.5
# Player 13(3.0) on slot 6 against 3.0
# Player 6(3.0) on slot 7 against 3.0
# Match 8
# Player 5(3.0) on slot 0 against 3.0
# Player 2(2.5) on slot 1 against 3.0
# Player 11(3.0) on slot 2 against 3.0
# Player 4(2.5) on slot 4 against 3.0
# Player 1(3.0) on slot 5 against 2.5
# Player 6(3.0) on slot 6 against 3.0
# Player 13(3.0) on slot 7 against 3.0
